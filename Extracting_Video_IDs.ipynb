# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilfaizal01/Semantic-Search-over-YT-Videos/blob/main/Extracting_Video_IDs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import polars as pl
from youtube_api_key import API_KEY

# %%
def getVideoRecords(response: requests.models.Response) -> list:
  """
  Function to extract YouTube video data from GET request response
  """
  video_record_list = []

  for raw_item in json.loads(response.text)['items']:
    # only execute for youtube videos
    if raw_item['id']['kind'] != "youtube#video":
      continue

    video_record = {}
    video_record['video_id'] = raw_item['id']['videoId']
    video_record['datetime'] = raw_item['snippet']['publishedAt']
    video_record['title'] = raw_item['snippet']['title']

    video_record_list.append(video_record)

  return video_record_list

# %%
# define channel ID
channel_id = 'UCCxmzh3f-wwRZ-bEdLb80Og'

# define url for API
url = 'https://www.googleapis.com/youtube/v3/search'

# initialize page token
page_token = None

# intialize list to store video data
video_record_list = []

# %%
# %%time
# extract video data across multiple search result pages
while page_token != 0:
  # define parameters for API call
  params = {"key": API_KEY, 'channelId': channel_id, 'part': ["snippet","id"], 'order': "date", 'maxResults':50, 'pageToken': page_token}
  # make get request
  response = requests.get(url, params=params)

  # append video records to list
  video_record_list += getVideoRecords(response)

  try:
    # grab next page token
    page_token = json.loads(response.text)['nextPageToken']
  except:
    # if no next page token kill while loop
    page_token = 0
# Out:
# CPU times: user 1.24 s, sys: 34.3 ms, total: 1.28 s
# Wall time: 6.5 s

# %%
video_record_list
# Out:
# [{'video_id': 'XT0WblJZqSo',
#   'datetime': '2024-07-04T20:00:09Z',
#   'title': 'Sheldon Gets Fired | The Big Bang Theory'},
#  {'video_id': 'P2A82K1sG48',
#   'datetime': '2024-07-04T12:00:21Z',
#   'title': 'Nerds and Their Moms | The Big Bang Theory #shorts'},
#  {'video_id': 'looMyVTPOn8',
#   'datetime': '2024-07-04T07:00:21Z',
#   'title': 'Funny Moments from Seasons 11 and 12 | The Big Bang Theory'},
#  {'video_id': 'j6YOTFV_w5M',
#   'datetime': '2024-07-03T20:00:16Z',
#   'title': 'Is Sheldon a Robot? | The Big Bang Theory'},
#  {'video_id': 'UUTQluNYg5I',
#   'datetime': '2024-07-03T17:00:19Z',
#   'title': 'Professor Proton Picks Leonard Over Sheldon | The Big Bang Theory'},
#  {'video_id': 'W6YoST3hOPQ',
#   'datetime': '2024-07-03T12:00:26Z',
#   'title': 'These Comic Book Guys Stay Lurking 👀 | The Big Bang Theory #shorts'},
#  {'video_id': 'Csnef25I-h4',
#   'datetime': '2024-07-02T20:00:04Z',
#   'title': 'The Sword of Azeroth | The Big Bang Theory'},
#  {'video_id': 'yRn_ESdW8Es',
#   'datetime': '2024-07-02T17:00:41Z',
#   'title': 'Leonard Rejects Penny&#39;s Proposal | The Big Bang Theory'},
#  {'video_id': 'Nrs8VZhaVTQ',
#   'datetime': '2024-07-02T12:00:32Z',
#   'title': 'The Girls Debate Over Thor&#39;s Hammer 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'e8izofJOJlU',
#   'datetime': '2024-07-01T20:00:25Z',
#   'title': 'Raj Speaks to Penny for the First Time | The Big Bang Theory'},
#  {'video_id': 'txeCzuxqmbg',
#   'datetime': '2024-07-01T17:00:40Z',
#   'title': 'Howard Loves Girls&#39; Night | The Big Bang Theory'},
#  {'video_id': '9wWC_rObwBY',
#   'datetime': '2024-07-01T14:00:06Z',
#   'title': 'Unforgettable Sheldon Cooper Moments (Season 5) | The Big Bang Theory'},
#  {'video_id': 'FqY91YPcoKY',
#   'datetime': '2024-07-01T12:00:15Z',
#   'title': 'Leonard Has Better Makeup Than Penny | The Big Bang Theory #shorts'},
#  {'video_id': 'fLwha2wcPVA',
#   'datetime': '2024-06-30T17:00:33Z',
#   'title': 'Sheldon Isn&#39;t Funny | The Big Bang Theory'},
#  {'video_id': 'k15DOfvW4rg',
#   'datetime': '2024-06-30T12:00:50Z',
#   'title': '&quot;Enterprise&quot; 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'a71rH2xdZC4',
#   'datetime': '2024-06-29T17:00:00Z',
#   'title': 'Howard Crashed the Mars Rover | The Big Bang Theory'},
#  {'video_id': '844Q1aMzDP4',
#   'datetime': '2024-06-29T12:00:05Z',
#   'title': 'When You&#39;re a Sore Loser | The Big Bang Theory #shorts'},
#  {'video_id': 'SMC3jYN5Oio',
#   'datetime': '2024-06-28T20:00:10Z',
#   'title': 'Howard Hooks Up with Christy | The Big Bang Theory'},
#  {'video_id': '684aD8slnjY',
#   'datetime': '2024-06-28T17:00:03Z',
#   'title': 'Sheldon Is a Terrible Liar | The Big Bang Theory'},
#  {'video_id': 'RQBmUMsLV1s',
#   'datetime': '2024-06-28T16:00:33Z',
#   'title': 'Catering Crises | The Big Bang Theory'},
#  {'video_id': '2VNt7MFKDL4',
#   'datetime': '2024-06-28T12:00:03Z',
#   'title': 'Amy Breaks Down | The Big Bang Theory #shorts'},
#  {'video_id': 'WGCW1fIikpE',
#   'datetime': '2024-06-27T20:00:22Z',
#   'title': 'The Flash⁴ | The Big Bang Theory'},
#  {'video_id': 'BWQiHL4_pF0',
#   'datetime': '2024-06-27T17:00:14Z',
#   'title': 'Leonard Hooks Up with Howard’s Date | The Big Bang Theory'},
#  {'video_id': '69cqd_0o4VM',
#   'datetime': '2024-06-27T14:00:06Z',
#   'title': 'Iconic Season 1 Moments (The Boys) | The Big Bang Theory'},
#  {'video_id': 'EhK7YKOetL4',
#   'datetime': '2024-06-27T12:00:12Z',
#   'title': 'Leonard Needs Help! | The Big Bang Theory #shorts'},
#  {'video_id': 'Q000ict3i-0',
#   'datetime': '2024-06-26T20:00:18Z',
#   'title': 'Superman Is Rife With Scientific Inaccuracy | The Big Bang Theory'},
#  {'video_id': 'S35qfgli1eE',
#   'datetime': '2024-06-26T17:00:27Z',
#   'title': 'Howard Tries Peacocking | The Big Bang Theory'},
#  {'video_id': 'cP13Hi0UAZE',
#   'datetime': '2024-06-26T12:00:28Z',
#   'title': 'You and Stuart... Why? | The Big Bang Theory #shorts'},
#  {'video_id': 'rBzE5yW2RMk',
#   'datetime': '2024-06-25T20:00:16Z',
#   'title': 'Raj’s First Interaction With Penny | The Big Bang Theory'},
#  {'video_id': 'wuELM-XQDlM',
#   'datetime': '2024-06-25T17:00:45Z',
#   'title': 'The Girls Go to the Comic Book Store | The Big Bang Theory'},
#  {'video_id': '4t214SOmffk',
#   'datetime': '2024-06-25T12:00:05Z',
#   'title': 'Roller Buddies | The Big Bang Theory #shorts'},
#  {'video_id': 'V40VgN4cq78',
#   'datetime': '2024-06-24T20:00:08Z',
#   'title': 'Sheldon and Leonard Sneak Into Penny&#39;s Room | The Big Bang Theory'},
#  {'video_id': 'JTaofpl-frQ',
#   'datetime': '2024-06-24T14:00:11Z',
#   'title': 'Unforgettable Leonard Moments (Season 3) | The Big Bang Theory'},
#  {'video_id': 'W7eLFFyRVd4',
#   'datetime': '2024-06-24T13:00:34Z',
#   'title': 'Getting to 3rd Base | The Big Bang Theory #shorts'},
#  {'video_id': 'h7K_JjWB_wk',
#   'datetime': '2024-06-23T17:00:34Z',
#   'title': 'Leonard Gets Proof that Penny Is Real | The Big Bang Theory'},
#  {'video_id': 'qfQDdjrMIbI',
#   'datetime': '2024-06-22T17:00:25Z',
#   'title': 'The Girls Debate Thor&#39;s Hammer | The Big Bang Theory'},
#  {'video_id': 'dfn4w71UlUw',
#   'datetime': '2024-06-21T20:00:13Z',
#   'title': 'Sheldon and Leonard Meet Penny | The Big Bang Theory'},
#  {'video_id': 'OqmuEW9yUiQ',
#   'datetime': '2024-06-21T17:00:26Z',
#   'title': 'Penny Ruins Laundry Night for Sheldon | The Big Bang Theory'},
#  {'video_id': 'AcbV2Os_V9A',
#   'datetime': '2024-06-21T15:00:17Z',
#   'title': 'Musical Acts | The Big Bang Theory'},
#  {'video_id': 'q6aiLW8nWwc',
#   'datetime': '2024-06-21T13:01:00Z',
#   'title': 'The #1 Most Common Name in the World 🌎 | The Big Bang Theory #shorts'},
#  {'video_id': 'rl_fQGwHZr4',
#   'datetime': '2024-06-20T17:00:37Z',
#   'title': 'Sheldon and Penny do Yoga | The Big Bang Theory'},
#  {'video_id': 'mPkz_IcJAQ8',
#   'datetime': '2024-06-20T14:00:41Z',
#   'title': 'Hilarious Howard Moments (Season 12) | The Big Bang Theory'},
#  {'video_id': '5SZxS3Uf7BA',
#   'datetime': '2024-06-20T13:00:05Z',
#   'title': 'Raj Loves America 🇺🇸 | The Big Bang Theory #shorts'},
#  {'video_id': '4xyg9ZY-DTw',
#   'datetime': '2024-06-19T20:00:02Z',
#   'title': 'Howard and Raj Kiss...Through the Internet | The Big Bang Theory'},
#  {'video_id': 'ohQaA524yfU',
#   'datetime': '2024-06-19T17:00:38Z',
#   'title': 'Penny Banishes Sheldon from The Cheesecake Factory | The Big Bang Theory'},
#  {'video_id': 'pJyXh25gQVc',
#   'datetime': '2024-06-19T12:00:58Z',
#   'title': 'Amy Looks Weird Without Her Glasses | The Big Bang Theory #shorts'},
#  {'video_id': 'oEMnXKhk36M',
#   'datetime': '2024-06-18T21:34:17Z',
#   'title': 'Penny and Raj in Bed Together?! | The Big Bang Theory'},
#  {'video_id': '9lbvW4BnyNY',
#   'datetime': '2024-06-18T17:00:06Z',
#   'title': 'Leonard Badly Misreads the Situation | The Big Bang Theory'},
#  {'video_id': 'ojW4DjNiIUo',
#   'datetime': '2024-06-17T20:00:38Z',
#   'title': 'Leonard Asks Penny for a Favor | The Big Bang Theory'},
#  {'video_id': '-vnoTjlCoyA',
#   'datetime': '2024-06-17T17:00:00Z',
#   'title': 'Sheldon Is Being Forced to Take a Vacation | The Big Bang Theory'},
#  {'video_id': '-vnoTjlCoyA',
#   'datetime': '2024-06-17T17:00:00Z',
#   'title': 'Sheldon Is Being Forced to Take a Vacation | The Big Bang Theory'},
#  {'video_id': 'OxEc_epF7vM',
#   'datetime': '2024-06-17T14:00:12Z',
#   'title': 'Unforgettable Leonard Moments (Season 2) | The Big Bang Theory'},
#  {'video_id': 'gb_EV_OZ5yg',
#   'datetime': '2024-06-17T12:00:42Z',
#   'title': 'Sheldon Feels Snubbed | The Big Bang Theory #shorts'},
#  {'video_id': 'a8ekf7xxySo',
#   'datetime': '2024-06-16T17:00:01Z',
#   'title': 'Bernadette Ruins a Rare Comic Book | The Big Bang Theory'},
#  {'video_id': 'lcFr808_0Jk',
#   'datetime': '2024-06-16T12:00:50Z',
#   'title': 'Howard and Raj Had the Best Bromance | The Big Bang Theory #shorts'},
#  {'video_id': '-hj9-lmttyM',
#   'datetime': '2024-06-15T17:00:00Z',
#   'title': 'Leonard and Penny Make Dinner Awkward for Everyone | The Big Bang Theory'},
#  {'video_id': 'kkWsVneI4u0',
#   'datetime': '2024-06-15T12:00:54Z',
#   'title': 'Sheldon Discovers Self-Massage | The Big Bang Theory #shorts'},
#  {'video_id': 'i_clg25beMU',
#   'datetime': '2024-06-14T17:00:34Z',
#   'title': 'Sheldon Travels to Flatland | The Big Bang Theory'},
#  {'video_id': '0WExy7I-bgA',
#   'datetime': '2024-06-14T16:00:01Z',
#   'title': 'Zany Zoological Moments | The Big Bang Theory'},
#  {'video_id': 'gOPio7mgNyE',
#   'datetime': '2024-06-14T12:00:45Z',
#   'title': 'Leonard Has Tummy Issues | The Big Bang Theory #shorts'},
#  {'video_id': '4rHq0auphws',
#   'datetime': '2024-06-13T20:00:01Z',
#   'title': 'Penny’s Admirer Shows up at Her Door | The Big Bang Theory'},
#  {'video_id': '22KbpBEOJAo',
#   'datetime': '2024-06-13T20:00:02Z',
#   'title': 'Sheldon Has to Invite His Brother to His Wedding | The Big Bang Theory'},
#  {'video_id': 'iOkRJzwlnAw',
#   'datetime': '2024-06-13T14:00:37Z',
#   'title': 'Unforgettable Sheldon Cooper Moments (Season 4) | The Big Bang Theory'},
#  {'video_id': 'OaQsv4LoReY',
#   'datetime': '2024-06-13T12:00:24Z',
#   'title': 'Sheldon Got LAWYERED | The Big Bang Theory #shorts'},
#  {'video_id': '97cwa8tyblw',
#   'datetime': '2024-06-12T20:00:06Z',
#   'title': 'Hannah Montana as explained by Raj | The Big Bang Theory'},
#  {'video_id': '15cuAzuELOc',
#   'datetime': '2024-06-12T20:00:00Z',
#   'title': 'Sheldon Asks for Half a Billion Dollars | The Big Bang Theory'},
#  {'video_id': 'fI5n8s23Obk',
#   'datetime': '2024-06-12T12:00:44Z',
#   'title': 'Sheldon Goes Dancing | The Big Bang Theory #shorts'},
#  {'video_id': 'DHPZldOBo0Y',
#   'datetime': '2024-06-11T20:00:05Z',
#   'title': 'Howard and Raj Spy on Leonard’s Date With Penny | The Big Bang Theory'},
#  {'video_id': 'T5j0oNct3rE',
#   'datetime': '2024-06-11T12:00:26Z',
#   'title': 'Death Star Cake | The Big Bang Theory #shorts'},
#  {'video_id': 'sRenf7VqACo',
#   'datetime': '2024-06-10T17:00:37Z',
#   'title': 'Howard Walks in on Leonard and Penny | The Big Bang Theory'},
#  {'video_id': 's1IPhnjHpSk',
#   'datetime': '2024-06-10T14:00:41Z',
#   'title': 'Funny Moments from Seasons 2 and 3 | The Big Bang Theory'},
#  {'video_id': 'IoVMRL60h8U',
#   'datetime': '2024-06-10T12:00:30Z',
#   'title': 'Star Wars Christmas? | The Big Bang Theory #shorts'},
#  {'video_id': 'RN-J5B1XBm0',
#   'datetime': '2024-06-09T12:00:24Z',
#   'title': 'Bernadette&#39;s Burnout Is Real 😥 | The Big Bang Theory #shorts'},
#  {'video_id': 'zBpn9vsjscs',
#   'datetime': '2024-06-08T12:01:06Z',
#   'title': 'Stuarts Retirement Plan 😂 | The Big Bang Theory #shorts'},
#  {'video_id': '52oVFesJ2Ew',
#   'datetime': '2024-06-07T23:00:05Z',
#   'title': 'Penny and Raj Discover a New Comet | The Big Bang Theory'},
#  {'video_id': 'GzW2rmwWlU8',
#   'datetime': '2024-06-07T22:00:22Z',
#   'title': 'Amy&#39;s Wedding Dress | The Big Bang Theory'},
#  {'video_id': 'JFCmYrNJnms',
#   'datetime': '2024-06-07T21:30:03Z',
#   'title': 'Everyone&#39;s Got Pink Eye | The Big Bang Theory'},
#  {'video_id': 'usT-sw1xYxQ',
#   'datetime': '2024-06-07T20:00:30Z',
#   'title': 'Bernadette Hacks Her New Mommy Brain | The Big Bang Theory'},
#  {'video_id': 'hwJad0_4zmA',
#   'datetime': '2024-06-07T12:00:47Z',
#   'title': 'Sheldon Is Zero Help | The Big Bang Theory #shorts'},
#  {'video_id': 'XmiPD0lhTWc',
#   'datetime': '2024-06-06T20:00:19Z',
#   'title': 'Hold the Door! | The Big Bang Theory'},
#  {'video_id': 'Y8LZQQFYkvM',
#   'datetime': '2024-06-06T14:00:23Z',
#   'title': 'Emotional Moments From the Final Season of ‘The Big Bang Theory&#39;'},
#  {'video_id': 'lMvUg84HbFg',
#   'datetime': '2024-06-06T12:00:46Z',
#   'title': 'Who Else Has Done Something Like This? 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'iPOPeAMqQKs',
#   'datetime': '2024-06-05T20:00:23Z',
#   'title': 'Stuart Flirts With the Spanish-Speaking Nannies | The Big Bang Theory'},
#  {'video_id': 'v93CTdPw8DM',
#   'datetime': '2024-06-05T17:00:43Z',
#   'title': 'Bernadette Plays &#39;Fortnite&#39; | The Big Bang Theory'},
#  {'video_id': 'dzIVFNa00tI',
#   'datetime': '2024-06-05T12:00:41Z',
#   'title': 'Penny Can&#39;t Be Poached 🙅 | The Big Bang Theory #shorts'},
#  {'video_id': 'H0lHqTr4oCM',
#   'datetime': '2024-06-04T17:00:08Z',
#   'title': 'Raj Hears Leonard In Trouble | The Big Bang Theory'},
#  {'video_id': '67y0bg_rzdc',
#   'datetime': '2024-06-04T12:00:07Z',
#   'title': 'The Most Shocking Moment In the Entire Series 😱 | The Big Bang Theory #shorts'},
#  {'video_id': 'RJvzFKtF45w',
#   'datetime': '2024-06-03T20:00:08Z',
#   'title': 'The Bat Signal | The Big Bang Theory'},
#  {'video_id': 'oK8cHxOESE0',
#   'datetime': '2024-06-03T17:00:36Z',
#   'title': 'Amy Finally Breaks Down | The Big Bang Theory'},
#  {'video_id': 'f5u1ruhNyA0',
#   'datetime': '2024-06-03T14:00:27Z',
#   'title': 'Memorable Bernadette Moments (Season 4) | The Big Bang Theory'},
#  {'video_id': 'xHO9LSSUCEs',
#   'datetime': '2024-06-03T12:01:02Z',
#   'title': 'Penny Runs a Tight Ship \U0001fae1 | The Big Bang Theory #shorts'},
#  {'video_id': 'GcNUECybAYI',
#   'datetime': '2024-06-02T17:00:09Z',
#   'title': 'Raj Decides Who He Wants To Live With | The Big Bang Theory'},
#  {'video_id': 'j2hmMJjY6QQ',
#   'datetime': '2024-06-02T12:00:43Z',
#   'title': 'Sheldon Loves Baby Testing 👶🏼 | The Big Bang Theory #shorts'},
#  {'video_id': 'YEA4qdadsZw',
#   'datetime': '2024-06-01T17:00:29Z',
#   'title': 'Bernadette Gets Verbally Abusive Video Game Coaching | The Big Bang Theory'},
#  {'video_id': 'IdEt4A0tsuM',
#   'datetime': '2024-06-01T12:00:24Z',
#   'title': 'Bernadette Wrote a Book About Howard 📕 | The Big Bang Theory #shorts'},
#  {'video_id': 'yA1z_hDG8Pw',
#   'datetime': '2024-05-31T12:01:03Z',
#   'title': 'That Word Isn&#39;t &#39;Thank&#39; 🤬 | The Big Bang Theory #shorts'},
#  {'video_id': 'x87lGRSC7o8',
#   'datetime': '2024-05-30T20:00:30Z',
#   'title': 'Bernadette Gets Help Inducing Labor | The Big Bang Theory'},
#  {'video_id': 'c26y5leItoo',
#   'datetime': '2024-05-30T18:00:20Z',
#   'title': 'Stuart and Raj Need to Grow Up | The Big Bang Theory'},
#  {'video_id': '1wLYkWDKkx4',
#   'datetime': '2024-05-30T16:07:45Z',
#   'title': 'Memorable Penny Moments (Season 1) | The Big Bang Theory'},
#  {'video_id': 'pACgm9alFPQ',
#   'datetime': '2024-05-30T12:00:55Z',
#   'title': 'Howard Reads &#39;The Frightened Little Astronaut&#39; 👩\u200d🚀 | The Big Bang Theory #shorts'},
#  {'video_id': 'tdEgEnFfxdM',
#   'datetime': '2024-05-29T17:00:38Z',
#   'title': 'Sheldon Reveals Which Friend He’d Eat First | The Big Bang Theory'},
#  {'video_id': 'Vbn9aWOWouo',
#   'datetime': '2024-05-29T12:00:33Z',
#   'title': 'There&#39;s Few People Sheldon Cooper Hasn&#39;t Insulted 😬 | The Big Bang Theory #shorts'},
#  {'video_id': '9bZBBNORzuw',
#   'datetime': '2024-05-28T20:00:03Z',
#   'title': 'Sheldon Invents Empathy | The Big Bang Theory'},
#  {'video_id': 'i9CpT91tXr8',
#   'datetime': '2024-05-28T17:00:25Z',
#   'title': 'Sheldon and Amy Play &#39;Heads Up&#39; | The Big Bang Theory'},
#  {'video_id': 'jt-nO8q3Cjc',
#   'datetime': '2024-05-28T12:00:50Z',
#   'title': 'Do They Have Mexican Food In Cuba? 🇨🇺 | The Big Bang Theory #shorts'},
#  {'video_id': 'iVA7vDx7o2U',
#   'datetime': '2024-05-27T20:00:11Z',
#   'title': 'Sheldon Rents His Old Room | The Big Bang Theory'},
#  {'video_id': 'DH8yDcjLQFU',
#   'datetime': '2024-05-27T14:00:07Z',
#   'title': 'Unforgettable Sheldon Cooper Moments (Season 3) | The Big Bang Theory'},
#  {'video_id': '24BVs-Dh-QQ',
#   'datetime': '2024-05-26T12:00:04Z',
#   'title': 'Sheldon Couldn&#39;t Have Been Happier in this Moment 😆 | The Big Bang Theory #shorts'},
#  {'video_id': 'xCQNfx6C60s',
#   'datetime': '2024-05-25T14:00:50Z',
#   'title': 'Sheldon&#39;s Mars Application Video | The Big Bang Theory'},
#  {'video_id': 'dEyiFQDFGdY',
#   'datetime': '2024-05-25T12:00:39Z',
#   'title': 'Amy&#39;s Annual Birthday Gift 🎉  | The Big Bang Theory #shorts'},
#  {'video_id': 'RlDhd7TaOWc',
#   'datetime': '2024-05-24T20:51:33Z',
#   'title': 'Raj Meets Nell | The Big Bang Theory'},
#  {'video_id': 'f13Z4cY83hE',
#   'datetime': '2024-05-24T17:00:34Z',
#   'title': 'The Relationship Agreement | The Big Bang Theory'},
#  {'video_id': 'SCBtURIr-HQ',
#   'datetime': '2024-05-24T12:00:34Z',
#   'title': 'Who Is Sleeping on Sheldon&#39;s Couch? 😴 | The Big Bang Theory #shorts'},
#  {'video_id': 'mO9UV0UPRgQ',
#   'datetime': '2024-05-23T20:00:15Z',
#   'title': 'Penny Lied Regarding Bernadette&#39;s Pregnancy | The Big Bang Theory'},
#  {'video_id': 'EKUL_Ny4GK0',
#   'datetime': '2024-05-23T14:00:20Z',
#   'title': 'Hilarious Howard &amp; Raj Moments | The Big Bang Theory'},
#  {'video_id': 'nDfntKSjQ6o',
#   'datetime': '2024-05-23T12:00:45Z',
#   'title': 'Leonard Finds Out Why He Can&#39;t Touch the Display 😬 | The Big Bang Theory #shorts'},
#  {'video_id': 'ofCbqG3RiHU',
#   'datetime': '2024-05-22T20:00:18Z',
#   'title': 'Penny Connects with Sheldon&#39;s Mom | The Big Bang Theory'},
#  {'video_id': '2exM8WI5lAI',
#   'datetime': '2024-05-22T17:00:01Z',
#   'title': 'Sheldon and Amy Make Out | The Big Bang Theory'},
#  {'video_id': '281vdyyOLlI',
#   'datetime': '2024-05-22T12:00:05Z',
#   'title': 'Sheldon Found a Loophole 😂 | The Big Bang Theory #shorts'},
#  {'video_id': '43_sQ2EzMk0',
#   'datetime': '2024-05-21T20:00:02Z',
#   'title': 'Zack Ruins it for Raj | The Big Bang Theory'},
#  {'video_id': '6n7QndOtp6I',
#   'datetime': '2024-05-21T17:00:06Z',
#   'title': 'Leonard and Penny Want a Relationship Agreement | The Big Bang Theory'},
#  {'video_id': 'ApZbIXQelg4',
#   'datetime': '2024-05-21T12:00:17Z',
#   'title': 'Penny Sold Leonard Out HARD 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'YwzmarxgG24',
#   'datetime': '2024-05-20T20:00:16Z',
#   'title': 'Leonard Won&#39;t Participate in the Mandatory Quarterly Roommate Agreement Meeting | Big Bang Theory'},
#  {'video_id': 'j0whbIXjD8A',
#   'datetime': '2024-05-20T17:00:32Z',
#   'title': 'If Howard and Raj Were Gay | The Big Bang Theory'},
#  {'video_id': 'rpa46vgM_sM',
#   'datetime': '2024-05-20T14:00:45Z',
#   'title': 'Season 1 Hilarious Moments | The Big Bang Theory'},
#  {'video_id': 'Tj0XeQ6Vnmo',
#   'datetime': '2024-05-20T12:00:22Z',
#   'title': 'Sheldon Forbids Amy from Physical Contact with Other Men | The Big Bang Theory #shorts'},
#  {'video_id': 'OIYqOVP5Lq8',
#   'datetime': '2024-05-19T17:00:21Z',
#   'title': 'Leonard Takes Penny for Granted | The Big Bang Theory'},
#  {'video_id': 'i2cMufNyCd4',
#   'datetime': '2024-05-19T12:00:39Z',
#   'title': 'Bernadette Got Sick Watching the Teacups Ride 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'ntHr7UrE88A',
#   'datetime': '2024-05-18T17:00:33Z',
#   'title': 'Sheldon Attempts To Engage in Small Talk | The Big Bang Theory'},
#  {'video_id': 'faHajcV8SRQ',
#   'datetime': '2024-05-18T12:00:40Z',
#   'title': 'Amy Is Not a Frog 🐸 | The Big Bang Theory #shorts'},
#  {'video_id': '1ZzFFkYdjWA',
#   'datetime': '2024-05-17T20:00:00Z',
#   'title': 'Riddle Me This, Man-Bat! | The Big Bang Theory'},
#  {'video_id': 'jm6HxKYzXXU',
#   'datetime': '2024-05-17T12:00:45Z',
#   'title': '&quot;WE WON THE NOBEL PRIZE&quot; 🏅 | The Big Bang Theory #shorts'},
#  {'video_id': 'Qi5G0r5_Xfw',
#   'datetime': '2024-05-16T20:00:14Z',
#   'title': 'Stuart the Stand-in | The Big Bang Theory'},
#  {'video_id': 'PkdyiJI4GIw',
#   'datetime': '2024-05-16T17:00:14Z',
#   'title': 'Bernadette&#39;s Backyard Retreat | The Big Bang Theory'},
#  {'video_id': 'WiGWpSM19Uo',
#   'datetime': '2024-05-16T14:00:32Z',
#   'title': 'Relationship Agreement Moments | The Big Bang Theory'},
#  {'video_id': '_4lC_J5PfNE',
#   'datetime': '2024-05-16T12:00:27Z',
#   'title': 'Penny Proposes for the Second Time 💍 | The Big Bang Theory #shorts'},
#  {'video_id': 'UDY7F6nFflU',
#   'datetime': '2024-05-15T20:00:18Z',
#   'title': 'Raj Is Stubborn | The Big Bang Theory'},
#  {'video_id': '1NjIxQFyVvw',
#   'datetime': '2024-05-15T14:00:03Z',
#   'title': 'Sheldon&#39;s Version of &quot;Helping&quot; | The Big Bang Theory'},
#  {'video_id': 'YeDpGfA0Rz0',
#   'datetime': '2024-05-15T12:00:36Z',
#   'title': 'One of the Sweetest Moments from &#39;The Big Bang Theory&#39; 🥲 #shorts'},
#  {'video_id': 'Wo6TMFBEUV8',
#   'datetime': '2024-05-14T20:00:18Z',
#   'title': 'Howard and Bernadette&#39;s Baby Announcement | The Big Bang Theory'},
#  {'video_id': 'ytaXqqz9BKY',
#   'datetime': '2024-05-14T14:00:46Z',
#   'title': 'Amy&#39;s Sensory Deprivation Experiment | The Big Bang Theory'},
#  {'video_id': 'j6lrXvNtKeA',
#   'datetime': '2024-05-14T12:00:44Z',
#   'title': 'Howard&#39;s Al Pacino Impression 🤣 | The Big Bang Theory #shorts'},
#  {'video_id': 'htzsZHNTQfg',
#   'datetime': '2024-05-13T20:00:12Z',
#   'title': 'Raj Meets Claire | The Big Bang Theory'},
#  {'video_id': 'X8M5d6qYiTQ',
#   'datetime': '2024-05-13T14:00:32Z',
#   'title': 'Season 2 Hilarious Moments | The Big Bang Theory'},
#  {'video_id': 'E4ejOWMZloM',
#   'datetime': '2024-05-13T12:00:16Z',
#   'title': 'The Best Couple? 🤔 | The Big Bang Theory #shorts'},
#  {'video_id': 'qQjKk_MBqTE',
#   'datetime': '2024-05-12T14:00:39Z',
#   'title': 'Bernadette&#39;s Mommy Burnout | The Big Bang Theory'},
#  {'video_id': 'hm4vS_kMhUo',
#   'datetime': '2024-05-12T12:00:40Z',
#   'title': 'It&#39;s Not a Date 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'k2J_DGPuCmQ',
#   'datetime': '2024-05-11T19:00:30Z',
#   'title': 'Raj Romances a Custodian | The Big Bang Theory'},
#  {'video_id': 'zdeI-xEcm5c',
#   'datetime': '2024-05-11T12:01:01Z',
#   'title': 'Sheldon Leaks Penny&#39;s Pregnancy 🤰 | The Big Bang Theory #shorts'},
#  {'video_id': '2eBbLeuLcvs',
#   'datetime': '2024-05-10T20:00:01Z',
#   'title': 'Amy Meets Meemaw | The Big Bang Theory'},
#  {'video_id': 'c1NtGONrzVk',
#   'datetime': '2024-05-10T12:00:40Z',
#   'title': 'Sheldon Doesn&#39;t Like Amy&#39;s Makeover 💇\u200d♀️ | The Big Bang Theory #shorts'},
#  {'video_id': '04jPLP7txKo',
#   'datetime': '2024-05-09T22:00:00Z',
#   'title': 'Memorable Mom Moments | The Big Bang Theory'},
#  {'video_id': 'XFZw6w2MRFM',
#   'datetime': '2024-05-09T20:00:12Z',
#   'title': 'Sheldon and Amy Ridicule Brian Greene | The Big Bang Theory'},
#  {'video_id': 'd2sUgVdUOd8',
#   'datetime': '2024-05-09T12:00:38Z',
#   'title': 'How&#39;s &quot;Shut Up?&quot; 🤔 | The Big Bang Theory #shorts'},
#  {'video_id': 'NlQiH3FGrMw',
#   'datetime': '2024-05-08T20:00:06Z',
#   'title': 'Raj Doesn’t Like Stan Lee’s Characters’ Names | The Big Bang Theory'},
#  {'video_id': 'm0kdWwH8ZM8',
#   'datetime': '2024-05-08T19:00:20Z',
#   'title': 'Sheldon Wants to &quot;Make a Baby&quot; | The Big Bang Theory'},
#  {'video_id': 'DGvigb_kKA8',
#   'datetime': '2024-05-08T12:00:13Z',
#   'title': 'Bernadette Goes Zero Gravity 🛩️  | The Big Bang Theory #shorts'},
#  {'video_id': 'yIA1DabfY4o',
#   'datetime': '2024-05-07T20:00:29Z',
#   'title': 'Howard Proposes to Bernadette'},
#  {'video_id': 'WH3e5ifeLYM',
#   'datetime': '2024-05-07T14:00:21Z',
#   'title': 'Leonard Comforts Sheldon | The Big Bang Theory'},
#  {'video_id': 'C3oYOzGojhc',
#   'datetime': '2024-05-07T12:00:09Z',
#   'title': '&quot;Don&#39;t Be Proud of That&quot; 😶| The Big Bang Theory #shorts'},
#  {'video_id': 'lTtrngtsTRk',
#   'datetime': '2024-05-06T20:00:13Z',
#   'title': 'Sheldon is an Intruder | The Big Bang Theory'},
#  {'video_id': 'Kk5Bkpufr7A',
#   'datetime': '2024-05-06T18:00:09Z',
#   'title': 'Penny Proposes at a Funeral | The Big Bang Theory'},
#  {'video_id': 'Y8gXIjNW6L4',
#   'datetime': '2024-05-06T12:00:24Z',
#   'title': 'Leonard&#39;s Room Gets a Makeover ✨ | The Big Bang Theory'},
#  {'video_id': 'kFzdCyIJEUw',
#   'datetime': '2024-05-05T12:00:40Z',
#   'title': 'Meryl Streep Has Chemistry with Everyone 🧪  | The Big Bang Theory #shorts'},
#  {'video_id': 'y7RaG74c2Dg',
#   'datetime': '2024-05-04T12:00:51Z',
#   'title': 'Penny Is &quot;Mama&quot; 👶 | The Big Bang Theory #shorts'},
#  {'video_id': 'nUNZM0_VN3w',
#   'datetime': '2024-05-03T20:00:28Z',
#   'title': 'Bernadette’s First Introduction to the Group | The Big Bang Theory'},
#  {'video_id': 'nnuQFb66Vmo',
#   'datetime': '2024-05-03T14:00:41Z',
#   'title': 'The Death Star Cake | The Big Bang Theory'},
#  {'video_id': 'LotBpSmr554',
#   'datetime': '2024-05-03T12:00:31Z',
#   'title': 'Sheldon Loves Geology 🪨 | The Big Bang Theory #shorts'},
#  {'video_id': 'wBwl4vCNjzg',
#   'datetime': '2024-05-02T20:00:30Z',
#   'title': 'Leonard&#39;s Mom is Getting a Divorce | The Big Bang Theory'},
#  {'video_id': '44aCbsvbz3Y',
#   'datetime': '2024-05-02T14:00:04Z',
#   'title': 'Season 3 Hilarious Moments | The Big Bang Theory'},
#  {'video_id': 'wjZolRA9zFU',
#   'datetime': '2024-05-02T12:00:49Z',
#   'title': 'Howard&#39;s Indian Accent 🐘 | The Big Bang Theory #shorts'},
#  {'video_id': 'ujEDhMyiKLg',
#   'datetime': '2024-05-01T20:00:17Z',
#   'title': 'Leonard&#39;s Mom Kisses Sheldon | The Big Bang Theory'},
#  {'video_id': 'r-T2Lu5NQq0',
#   'datetime': '2024-05-01T14:00:43Z',
#   'title': 'Sheldon and Amy Are the Superior Couple | The Big Bang Theory'},
#  {'video_id': 'J0VG39y3Mks',
#   'datetime': '2024-05-01T12:00:24Z',
#   'title': 'Raj&#39;s Date Is Deaf 🧏\u200d♀️ | The Big Bang Theory #shorts'},
#  {'video_id': 'Lyaxfh1qzEI',
#   'datetime': '2024-04-30T20:00:06Z',
#   'title': 'Penny Meets Leonard&#39;s Mom | The Big Bang Theory'},
#  {'video_id': 'P5bdRWvJDs0',
#   'datetime': '2024-04-30T14:00:18Z',
#   'title': 'Sheldon Is Contractually Obligated To Go on Dates | The Big Bang Theory'},
#  {'video_id': 'kbwXGLwMfl0',
#   'datetime': '2024-04-30T12:00:44Z',
#   'title': 'Howard&#39;s Invite Got Lost In the Matrix ✉️  | The Big Bang Theory #shorts'},
#  {'video_id': 'MZgHs-1vFKY',
#   'datetime': '2024-04-29T20:00:06Z',
#   'title': 'Raj and Howard&#39;s Dating Advice | The Big Bang Theory'},
#  {'video_id': '5umy2J_lYCc',
#   'datetime': '2024-04-29T14:00:05Z',
#   'title': 'Iconic &#39;Fun with Flags&#39; Moments | The Big Bang Theory'},
#  {'video_id': 'yMp3tPuIk38',
#   'datetime': '2024-04-29T12:00:54Z',
#   'title': 'Howard Gets Grounded.. on Earth 🌏 | The Big Bang Theory #shorts'},
#  {'video_id': 'QJKYiE2DpAU',
#   'datetime': '2024-04-28T14:00:25Z',
#   'title': 'Penny Gets Cozy with a Homeless Drug Addict | The Big Bang Theory'},
#  {'video_id': 'TzESiZqKVbM',
#   'datetime': '2024-04-28T12:00:32Z',
#   'title': 'Sheldon&#39;s Prank Backfires 📬  | The Big Bang Theory #shorts'},
#  {'video_id': 'gXL0ol29fj4',
#   'datetime': '2024-04-27T14:00:35Z',
#   'title': 'The Battle of Gettysburg with Condiments | The Big Bang Theory'},
#  {'video_id': '4Ml4PzlS6aw',
#   'datetime': '2024-04-27T12:00:05Z',
#   'title': 'Priya Messed Up A LOT 😬 | The Big Bang Theory #shorts'},
#  {'video_id': 'pm-Y1t9e-Hg',
#   'datetime': '2024-04-26T20:00:16Z',
#   'title': 'Howard Solves the Catering Crisis | The Big Bang Theory'},
#  {'video_id': 'CkaiD_Tv7EU',
#   'datetime': '2024-04-26T12:00:18Z',
#   'title': '&#39;Dungeons &amp; Dragons&#39; Gets Literal 🐉 | The Big Bang Theory #shorts'},
#  {'video_id': 'vdNHUFIWSFU',
#   'datetime': '2024-04-25T20:00:17Z',
#   'title': 'Sheldon Wants a Real Wedding | The Big Bang Theory'},
#  {'video_id': 'vRgpefHQP80',
#   'datetime': '2024-04-25T18:00:25Z',
#   'title': 'Tetris Arm Wrestling | The Big Bang Theory'},
#  {'video_id': 'Kd63X4hYxbk',
#   'datetime': '2024-04-25T14:00:24Z',
#   'title': 'Unforgettable Leonard Moments (Season 1) | The Big Bang Theory'},
#  {'video_id': 'qU7R1x5Sa7o',
#   'datetime': '2024-04-25T12:00:45Z',
#   'title': 'Bernadette Isn&#39;t Excited to be a Mom 👶 | The Big Bang Theory #shorts'},
#  {'video_id': 'gSHVZA5zqLU',
#   'datetime': '2024-04-24T20:00:25Z',
#   'title': 'Kripke Screws Leonard and Howard | The Big Bang Theory'},
#  {'video_id': 'ygQjNJbkirE',
#   'datetime': '2024-04-24T12:00:52Z',
#   'title': 'HOLY CRAP! 🐙 | The Big Bang Theory #shorts'},
#  {'video_id': 'DW3mqCG2fHc',
#   'datetime': '2024-04-23T20:00:08Z',
#   'title': 'Sheldon&#39;s Junk | The Big Bang Theory'},
#  {'video_id': 'xsuHU1MN-r8',
#   'datetime': '2024-04-23T14:00:47Z',
#   'title': 'Sheldon Doesn&#39;t Work Here | The Big Bang Theory'},
#  {'video_id': 'Zg3Q1wN-ToQ',
#   'datetime': '2024-04-23T12:00:28Z',
#   'title': 'Property of U? 🤔 | The Big Bang Theory #shorts'},
#  {'video_id': 'H_acKZ2vjNs',
#   'datetime': '2024-04-22T21:30:01Z',
#   'title': 'Leonard and Penny&#39;s First Date | The Big Bang Theory'},
#  {'video_id': 'sqCcMgf025E',
#   'datetime': '2024-04-22T20:00:30Z',
#   'title': 'Stuart Agrees to Move in with Denise | The Big Bang Theory'},
#  {'video_id': 'PxbS6w7RNqY',
#   'datetime': '2024-04-22T14:00:18Z',
#   'title': 'The Full Sheldon and Amy Story | The Big Bang Theory'},
#  {'video_id': 'Mr5ZoUR66Mw',
#   'datetime': '2024-04-22T12:00:29Z',
#   'title': 'Penny the Confrontational Waitress 😬 | The Big Bang Theory #shorts'},
#  {'video_id': 'ZTEpL6kBo5Y',
#   'datetime': '2024-04-21T14:00:32Z',
#   'title': 'Sheldon Wins Amy Back | The Big Bang Theory'},
#  {'video_id': 'ZTEpL6kBo5Y',
#   'datetime': '2024-04-21T14:00:32Z',
#   'title': 'Sheldon Wins Amy Back | The Big Bang Theory'},
#  {'video_id': 'BUdwy-W-2lk',
#   'datetime': '2024-04-21T12:00:13Z',
#   'title': 'The Romance Ninja 🥷 | The Big Bang Theory #shorts'},
#  {'video_id': 'pPGRCfLMsQI',
#   'datetime': '2024-04-20T14:00:40Z',
#   'title': 'Zero Gravity | The Big Bang Theory'},
#  {'video_id': 'rVOHV8jq5cw',
#   'datetime': '2024-04-20T12:00:57Z',
#   'title': 'Sheldon&#39;s Emergency Exits ⚠️ | The Big Bang Theory #shorts'},
#  {'video_id': 'gZm1XuikX-8',
#   'datetime': '2024-04-19T20:00:25Z',
#   'title': 'Leonard Forgives His Mother | The Big Bang Theory'},
#  {'video_id': 'y59S98LWVyk',
#   'datetime': '2024-04-19T14:00:54Z',
#   'title': 'Penny Throws Leonard Under the Bus | The Big Bang Theory'},
#  {'video_id': 'Emd3eFwnY98',
#   'datetime': '2024-04-19T12:00:26Z',
#   'title': 'Howard Bought a &#39;Star Trek&#39; Plate without Bernadette&#39;s Permission 😂 | The Big Bang Theory #shorts'},
#  {'video_id': '7Ldb0rjLLc0',
#   'datetime': '2024-04-18T20:00:04Z',
#   'title': 'Howard Doesn’t Want Raj To Leave to London'},
#  {'video_id': 'OE5AMySfP2k',
#   'datetime': '2024-04-18T18:00:19Z',
#   'title': 'Someone&#39;s Sleeping on Sheldon&#39;s Couch | The Big Bang Theory'},
#  {'video_id': 'idY-dr-n_Cw',
#   'datetime': '2024-04-18T14:00:29Z',
#   'title': 'Astronaut Howard Moments | The Big Bang Theory'},
#  {'video_id': 'w6UopMzmyoo',
#   'datetime': '2024-04-18T12:00:54Z',
#   'title': 'Sheldon Doesn&#39;t Want to Get Arrested 👮\u200d♂️  | The Big Bang Theory #shorts'},
#  {'video_id': 'Al7f2u2FFa4',
#   'datetime': '2024-04-17T20:00:04Z',
#   'title': 'Leonard Is No Longer a Satisficer | The Big Bang Theory'},
#  {'video_id': 'iacm1Uvt1m8',
#   'datetime': '2024-04-17T14:00:34Z',
#   'title': 'The Final Scene | The Big Bang Theory'},
#  {'video_id': 'BKikOmTdk28',
#   'datetime': '2024-04-17T12:00:11Z',
#   'title': 'Raj Can Talk to Women Now?! 😯  | The Big Bang Theory #shorts'},
#  {'video_id': 'Y9hdXuP26KI',
#   'datetime': '2024-04-16T14:00:21Z',
#   'title': 'Sheldon&#39;s Nobel Prize Acceptance Speech | The Big Bang Theory'},
#  {'video_id': 'NkNFTpC_dcc',
#   'datetime': '2024-04-16T12:00:17Z',
#   'title': 'The &quot;Morally Compromised&quot; Guys Win! 🏆 | The Big Bang Theory #shorts'},
#  {'video_id': 'nQwzXMHgkWk',
#   'datetime': '2024-04-15T20:00:14Z',
#   'title': 'Sheldon Hides From His Birthday Guests | The Big Bang Theory'},
#  {'video_id': '0Syz0sLMAGg',
#   'datetime': '2024-04-15T18:00:02Z',
#   'title': 'Penny Is Pregnant | The Big Bang Theory'},
#  {'video_id': 'wPQxfHNo_qk',
#   'datetime': '2024-04-15T14:00:40Z',
#   'title': 'Funny Moments from Season 12 | The Big Bang Theory'},
#  {'video_id': 'uzux2CUKWW4',
#   'datetime': '2024-04-14T14:00:39Z',
#   'title': 'Bernadette Is a Thrill Seeker | The Big Bang Theory'},
#  {'video_id': 'ZwcBOcQ-qg4',
#   'datetime': '2024-04-14T12:00:34Z',
#   'title': 'Howard&#39;s &#39;Stuart Voice&#39; 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'wGTwLku9_Zg',
#   'datetime': '2024-04-13T14:00:43Z',
#   'title': 'Bribing Nobel Prize Winners with Cookies | The Big Bang Theory'},
#  {'video_id': 'BR0SiS0Mgvc',
#   'datetime': '2024-04-13T12:00:12Z',
#   'title': 'The Essence of a Mexican Standoff 🇲🇽  | The Big Bang Theory #shorts'},
#  {'video_id': '2QRBwmJEQ8s',
#   'datetime': '2024-04-12T20:00:01Z',
#   'title': 'The Reason Sheldon Hates Birthdays | The Big Bang Theory'},
#  {'video_id': 'mtvFH8OgR8c',
#   'datetime': '2024-04-12T14:00:28Z',
#   'title': 'Someone Tries to Poach Penny | The Big Bang Theory'},
#  {'video_id': 'Yqo0eyYUSTg',
#   'datetime': '2024-04-12T12:00:25Z',
#   'title': 'Guys on Dating Apps 📱 | The Big Bang Theory #shorts'},
#  {'video_id': 'jIjgO9kEejM',
#   'datetime': '2024-04-11T20:00:13Z',
#   'title': 'President Siebert Doesn’t Want Sheldon To Do Interviews | The Big Bang Theory'},
#  {'video_id': 'oNnDnlKcyvA',
#   'datetime': '2024-04-11T14:00:39Z',
#   'title': 'Roommate Stuart Moments | The Big Bang Theory'},
#  {'video_id': 'XDkcLE2JouY',
#   'datetime': '2024-04-11T12:00:27Z',
#   'title': 'Sheldon Has No Idea How Bad This Looks 😳 | The Big Bang Theory #shorts'},
#  {'video_id': 'MTpwgvrPYvE',
#   'datetime': '2024-04-10T20:00:07Z',
#   'title': 'Howard Gets a Scooter | The Big Bang Theory'},
#  {'video_id': 'BjoDtw99wc8',
#   'datetime': '2024-04-10T14:00:08Z',
#   'title': 'Sheldon Needs To Think Before He Speaks | The Big Bang Theory'},
#  {'video_id': 'kYjre77iHKk',
#   'datetime': '2024-04-10T12:00:41Z',
#   'title': 'Goth Night 🖤 | The Big Bang Theory #shorts'},
#  {'video_id': '1DccYT2isHM',
#   'datetime': '2024-04-09T14:00:02Z',
#   'title': 'Sheldon Wants How Many Kids? | The Big Bang Theory'},
#  {'video_id': 'Th6LeQs5zpE',
#   'datetime': '2024-04-09T12:00:32Z',
#   'title': 'Bazinga, Punk! 🧟\u200d♂️ | The Big Bang Theory #shorts'},
#  {'video_id': 'AkUHVf_U5dM',
#   'datetime': '2024-04-08T20:00:03Z',
#   'title': 'Sheldon and Leonard Outsmart Kripke | The Big Bang Theory'},
#  {'video_id': 'uC2-ZLZyLAc',
#   'datetime': '2024-04-08T18:00:25Z',
#   'title': 'Penny Is a Tough Boss | The Big Bang Theory'},
#  {'video_id': 'uUI6dJ9Pr74',
#   'datetime': '2024-04-08T14:00:41Z',
#   'title': 'Unforgettable Sheldon Cooper Moments (Season 2) | The Big Bang Theory'},
#  {'video_id': 'SRO5SQmm7K8',
#   'datetime': '2024-04-08T12:00:31Z',
#   'title': 'Howard Makes His Move on Penny 😚 | The Big Bang Theory #shorts'},
#  {'video_id': 'b8SR2EGvNtg',
#   'datetime': '2024-04-07T14:00:20Z',
#   'title': 'Sheldon Insulted Several Nobel Prize Winners | The Big Bang Theory'},
#  {'video_id': 'WvoKXqn-YXs',
#   'datetime': '2024-04-07T12:00:24Z',
#   'title': 'Sheldon Hit the Override Switch 💥 | The Big Bang Theory #shorts'},
#  {'video_id': 'NQtTI3tyOZc',
#   'datetime': '2024-04-06T14:00:18Z',
#   'title': 'Baby Test Subjects | The Big Bang Theory'},
#  {'video_id': 'znOjvxMPVQw',
#   'datetime': '2024-04-06T12:00:53Z',
#   'title': 'Prom Night ✨ | The Big Bang Theory #shorts'},
#  {'video_id': 'WIDI56MU0cE',
#   'datetime': '2024-04-05T20:00:22Z',
#   'title': 'A Little Help From Kripke | The Big Bang Theory'},
#  {'video_id': 'eETKVzpdH20',
#   'datetime': '2024-04-05T14:00:35Z',
#   'title': 'Leonard Breaks the Molecule Display | The Big Bang Theory'},
#  {'video_id': '9wL9823MmPw',
#   'datetime': '2024-04-05T12:00:07Z',
#   'title': 'Penis Cookies 😶 | The Big Bang Theory #shorts'},
#  {'video_id': '0w4DxVJ4BUU',
#   'datetime': '2024-04-04T20:00:00Z',
#   'title': 'Women Find Howard Appealing | The Big Bang Theory'},
#  {'video_id': 'oTQa4ZWIC0A',
#   'datetime': '2024-04-04T14:00:39Z',
#   'title': 'Penny and Amy Moments | The Big Bang Theory'},
#  {'video_id': 'GVvEK_8PtCU',
#   'datetime': '2024-04-04T12:00:13Z',
#   'title': 'Sheldon Touches a Bird 🐦 | The Big Bang Theory #shorts'},
#  {'video_id': 'FXwoq46rlQw',
#   'datetime': '2024-04-03T20:00:04Z',
#   'title': 'Penny Gets Excited Over Leonard’s Game Night Story | The Big Bang Theory'},
#  {'video_id': 'uHONZJjNwZI',
#   'datetime': '2024-04-03T14:00:42Z',
#   'title': 'Sheldon and Amy Won a Nobel Prize | The Big Bang Theory'},
#  {'video_id': 'DjdAl2nWlDk',
#   'datetime': '2024-04-02T14:00:08Z',
#   'title': 'Sheldon Thinks It&#39;s 2003 🕰 | The Big Bang Theory #shorts'},
#  {'video_id': '5EdqMyMUwm0',
#   'datetime': '2024-04-02T14:00:06Z',
#   'title': 'Amy Gets a Makeover | The Big Bang Theory'},
#  {'video_id': 'udKdtdFE9Bg',
#   'datetime': '2024-04-01T20:00:16Z',
#   'title': 'The Wolowitz Coefficient | The Big Bang Theory'},
#  {'video_id': 'YeewkmNRaXE',
#   'datetime': '2024-04-01T18:00:26Z',
#   'title': 'The Freezer Survival Test | The Big Bang Theory'},
#  {'video_id': 'DvNHuUzZqT0',
#   'datetime': '2024-04-01T14:00:08Z',
#   'title': 'Pranks and Practical Jokes | The Big Bang Theory'},
#  {'video_id': 'zBaRumt2nEU',
#   'datetime': '2024-04-01T12:00:59Z',
#   'title': 'Leonard and Penny Make Each Other Look Bad 😂 | The Big Bang Theory #shorts'},
#  {'video_id': '8gU48gUmoqU',
#   'datetime': '2024-03-31T14:00:05Z',
#   'title': 'The Elevator Works?! | The Big Bang Theory'},
#  {'video_id': 'A-6QlatveIo',
#   'datetime': '2024-03-31T12:00:09Z',
#   'title': 'Sheldon Shoots His Shot 😏 | The Big Bang Theory #shorts'},
#  {'video_id': 'dRmXWwxk6sM',
#   'datetime': '2024-03-30T13:00:30Z',
#   'title': 'The Snake Prank 🐍 | The Big Bang Theory #shorts'},
#  {'video_id': 'Dis_Lt-C3ow',
#   'datetime': '2024-03-29T14:00:15Z',
#   'title': 'The Mexican Standoff | The Big Bang Theory'},
#  {'video_id': 'eo-qTfuXsV8',
#   'datetime': '2024-03-29T12:00:37Z',
#   'title': 'Did Raj Break the Bro Code? 🤔  | The Big Bang Theory #shorts'},
#  {'video_id': 'eVC7llpRQwg',
#   'datetime': '2024-03-28T17:00:26Z',
#   'title': 'Making Fun of Dating Profiles | The Big Bang Theory'},
#  {'video_id': 'D5brNz3UIcw',
#   'datetime': '2024-03-28T14:00:09Z',
#   'title': 'Unforgettable Sheldon Cooper Moments (Season 1) | The Big Bang Theory'},
#  {'video_id': 'NqWU5TeAjS4',
#   'datetime': '2024-03-28T13:00:30Z',
#   'title': 'The Mortal Enemies List 📝  | The Big Bang Theory #shorts'},
#  {'video_id': 'xVxWR2cTCJI',
#   'datetime': '2024-03-27T13:01:02Z',
#   'title': 'Later Losers! ✌️ | The Big Bang Theory #shorts'},
#  {'video_id': 'UvXmZJh9Z0Y',
#   'datetime': '2024-03-26T20:00:08Z',
#   'title': 'Sheldon and Howard Bond Over a Replica Saturn 5 Rocket | The Big Bang Theory'},
#  {'video_id': 'uql7SrQViGw',
#   'datetime': '2024-03-26T13:01:01Z',
#   'title': 'Sheldon and Penny Agree on Something 😯 | The Big Bang Theory #shorts'},
#  {'video_id': 'vMui7A1-_I0',
#   'datetime': '2024-03-25T20:00:18Z',
#   'title': 'Raj Wants To Break up With Emily | The Big Bang Theory'},
#  {'video_id': 'H-WAj_OgdmQ',
#   'datetime': '2024-03-25T18:00:11Z',
#   'title': 'Leonard and Priya: Forbidden Love | The Big Bang Theory'},
#  {'video_id': '-CBnuivgJFw',
#   'datetime': '2024-03-25T14:00:00Z',
#   'title': 'Leonard Cuts a Meteorite Open | The Big Bang Theory'},
#  {'video_id': 'MIIyL2UxHqg',
#   'datetime': '2024-03-25T13:00:29Z',
#   'title': 'Howard&#39;s Cousin / Ex-Lover 😬  | The Big Bang Theory #shorts'},
#  {'video_id': 'bRXWIJyyz1U',
#   'datetime': '2024-03-24T13:00:35Z',
#   'title': '&quot;¡Viva La Imodium!&quot; 🇲🇽 | The Big Bang Theory #shorts'},
#  {'video_id': 'F0LX70sBnLU',
#   'datetime': '2024-03-22T14:00:12Z',
#   'title': 'Sheldon and Amy Did it | The Big Bang Theory'},
#  {'video_id': 'STlcL1kYOGA',
#   'datetime': '2024-03-21T18:00:11Z',
#   'title': 'Funny Moments from Season 11 | The Big Bang Theory'},
#  {'video_id': 'vfjit_5gzQ0',
#   'datetime': '2024-03-21T14:00:41Z',
#   'title': 'Stephen Hawking Won&#39;t Play Sheldon Back | The Big Bang Theory'},
#  {'video_id': 'lu_Jik9AfV4',
#   'datetime': '2024-03-20T20:00:30Z',
#   'title': 'Raj and Howard Have Fans | The Big Bang Theory'},
#  {'video_id': 'Ks0KG93s5qs',
#   'datetime': '2024-03-20T14:00:22Z',
#   'title': 'Fun with Flags with Bickering | The Big Bang Theory'},
#  {'video_id': 'jB_5CJKSNsU',
#   'datetime': '2024-03-20T13:00:48Z',
#   'title': 'Raj Overhears Leonard Role Playing 🙉 | The Big Bang Theory #shorts'},
#  {'video_id': 'StbZXReJPJM',
#   'datetime': '2024-03-19T20:00:17Z',
#   'title': 'Penny Doesn’t Want To Work for Bernadette | The Big Bang Theory'},
#  {'video_id': '1_BkIEVIjZA',
#   'datetime': '2024-03-19T18:00:01Z',
#   'title': 'Howard&#39;s Impressions | The Big Bang Theory'},
#  {'video_id': 'h5X0jlLxTXE',
#   'datetime': '2024-03-19T16:00:36Z',
#   'title': 'The Costume Party | The Big Bang Theory'},
#  {'video_id': 'zXHasy0Dy_A',
#   'datetime': '2024-03-19T14:00:47Z',
#   'title': '&quot;Women Come In. Don&#39;t Be Afraid.&quot; 😶 | The Big Bang Theory'},
#  {'video_id': 'VHrF4GC2T4I',
#   'datetime': '2024-03-18T14:00:21Z',
#   'title': 'Howard Wants to Change His Answer 🤔 | The Big Bang Theory #shorts'},
#  {'video_id': 'AlBfPljtD90',
#   'datetime': '2024-03-17T14:00:06Z',
#   'title': 'Raj Got Into Leonard&#39;s Head 😂 | The Big Bang Theory #shorts'},
#  {'video_id': 'QwMwAe33T0Q',
#   'datetime': '2024-03-16T16:00:29Z',
#   'title': 'Howard&#39;s Stuart Impression is Uncanny | The Big Bang Theory'},
#  {'video_id': 'Umk2Q1cbdro',
#   'datetime': '2024-03-16T14:00:23Z',
#   'title': 'Sheldon Has a Bathroom Emergency 🚨 | The Big Bang Theory #shorts'},
#  {'video_id': 'd87l6h_K4fE',
#   'datetime': '2024-03-15T16:00:29Z',
#   'title': 'Sheldon Can&#39;t Say &quot;Geology&quot; | The Big Bang Theory'},
#  {'video_id': '9RCzfXaF-qU',
#   'datetime': '2024-03-15T14:00:06Z',
#   'title': 'The Relationship Sham 😚  | The Big Bang Theory #shorts'},
#  {'video_id': 'YcjVNmdlYaI',
#   'datetime': '2024-03-14T20:00:21Z',
#   'title': 'My Heart, My Universe | The Big Bang Theory'},
#  {'video_id': 'E1cj5Tyxr28',
#   'datetime': '2024-03-14T20:00:05Z',
#   'title': 'How Are You Celebrating National Pi Day? | The Big Bang Theory'},
#  {'video_id': 'IFKyghdZtQE',
#   'datetime': '2024-03-14T12:00:14Z',
#   'title': 'It&#39;s Too Brobdingnagian | The Big Bang Theory #shorts'},
#  {'video_id': 'gs_ZYIpc4MI',
#   'datetime': '2024-03-13T22:00:20Z',
#   'title': 'Penny Robs Sheldon of His Seat | The Big Bang Theory'},
#  {'video_id': '8fuvcmngGQI',
#   'datetime': '2024-03-13T16:00:10Z',
#   'title': 'Bernadette’s Baby Thinks Penny Is “Mama” | The Big Bang Theory'},
#  {'video_id': 'FOejqG7EKP0',
#   'datetime': '2024-03-13T14:00:09Z',
#   'title': 'Her Name was Glisinda the Troll 😈 | The Big Bang Theory #short'},
#  {'video_id': 'WPGj33JorXA',
#   'datetime': '2024-03-12T22:00:25Z',
#   'title': 'Sheldon Proclaims his Love for Amy | The Big Bang Theory'},
#  {'video_id': 'vvHSZhyo8Dg',
#   'datetime': '2024-03-12T14:00:42Z',
#   'title': 'The Best Gift Sheldon Could Have Given 🎁 | The Big Bang Theory #shorts'},
#  {'video_id': '8-IKq4lOhj4',
#   'datetime': '2024-03-11T17:30:01Z',
#   'title': 'Leonard Being Awkward | The Big Bang Theory'},
#  {'video_id': 'is5SKJuT6ds',
#   'datetime': '2024-03-11T16:00:28Z',
#   'title': 'Penny Reads Stuart&#39;s Online Reviews | The Big Bang Theory'},
#  {'video_id': 'zmnFjrVOwr0',
#   'datetime': '2024-03-11T16:00:43Z',
#   'title': 'Raj Puts His Girl on the Spot 😳 | The Big Bang Theory #shorts'},
#  {'video_id': 'pzfL-aEj9qY',
#   'datetime': '2024-03-10T16:00:36Z',
#   'title': 'Insect Flavored Snow Cones 🐛 🍨 | The Big Bang Theory #shorts'},
#  {'video_id': 'zmnFjrVOwr0',
#   'datetime': '2024-03-11T16:00:43Z',
#   'title': 'Raj Puts His Girl on the Spot 😳 | The Big Bang Theory #shorts'},
#  {'video_id': 'pzfL-aEj9qY',
#   'datetime': '2024-03-10T16:00:36Z',
#   'title': 'Insect Flavored Snow Cones 🐛 🍨 | The Big Bang Theory #shorts'},
#  {'video_id': 'NENia6-CTfA',
#   'datetime': '2024-03-08T21:00:17Z',
#   'title': 'Howard Wears a Sheldon Costume | The Big Bang Theory'},
#  {'video_id': 'xGOxe_5VsGI',
#   'datetime': '2024-03-08T17:00:49Z',
#   'title': 'Raj and Howard&#39;s Song Has No Groove | The Big Bang Theory'},
#  {'video_id': 'OFfV_d2G3DI',
#   'datetime': '2024-03-08T15:00:18Z',
#   'title': 'Thursday Is NOT Pizza Night 🍕 | The Big Bang Theory #shorts'},
#  {'video_id': '2Ferd3TuCQs',
#   'datetime': '2024-03-07T21:00:00Z',
#   'title': 'Sheldon’s About To Lose a Second Best Friend | The Big Bang Theory'},
#  {'video_id': 'OZXkcCscWMw',
#   'datetime': '2024-03-07T15:00:30Z',
#   'title': 'The Answer is Cheese Danish 🥮 | The Big Bang Theory #shorts'},
#  {'video_id': 'HR2Rb-GnKvI',
#   'datetime': '2024-03-07T15:00:24Z',
#   'title': 'The Evolution of Amy Farrah Fowler | The Big Bang Theory'},
#  {'video_id': '3VhnE65qjKg',
#   'datetime': '2024-03-06T17:00:06Z',
#   'title': 'Sheldon Reverts Back to 2003 | The Big Bang Theory'},
#  {'video_id': 'gDcBbmjmCEU',
#   'datetime': '2024-03-05T15:00:36Z',
#   'title': '100 Ways to Rip a Guys Nuts Off 🥜 | The Big Bang Theory #shorts'},
#  {'video_id': 'mdOmB-FRobE',
#   'datetime': '2024-03-04T23:50:09Z',
#   'title': 'Killer Robot Antics 🤖 | The Big Bang Theory #shorts'},
#  {'video_id': '65Fjaz9W7PA',
#   'datetime': '2024-03-04T21:00:02Z',
#   'title': 'Howard Is a Bad Friend | The Big Bang Theory'},
#  {'video_id': '7Ay-9Lp1eto',
#   'datetime': '2024-03-04T15:00:06Z',
#   'title': '5 Times Howard Wasn&#39;t Immediately Rejected | The Big Bang Theory'},
#  {'video_id': '8GgISNZu5xU',
#   'datetime': '2024-03-01T21:00:04Z',
#   'title': 'Sheldon Comforts Penny at the Hospital | The Big Bang Theory'},
#  {'video_id': 'TrGXxuS90Wo',
#   'datetime': '2024-03-01T18:00:27Z',
#   'title': 'Howard and Raj Date Goth Chicks | The Big Bang Theory'},
#  {'video_id': 'FphAbW22MRA',
#   'datetime': '2024-02-29T21:00:09Z',
#   'title': 'Raj’s Parents Want Him To Meet Lakshmi | The Big Bang Theory'},
#  {'video_id': 'zEneaWUkDNI',
#   'datetime': '2024-02-28T21:00:39Z',
#   'title': 'Everyone’s Fighting and Sheldon Loses It | The Big Bang Theory'},
#  {'video_id': 'LdH3fbuPLFg',
#   'datetime': '2024-02-26T21:00:17Z',
#   'title': 'Professor Roger Abbott&#39;s Notes | The Big Bang Theory'},
#  {'video_id': '5zPK7rqro1A',
#   'datetime': '2024-02-26T17:00:08Z',
#   'title': 'Leonard and Penny Are Getting Married Again | The Big Bang Theory'},
#  {'video_id': 'VOJeWBqoJ_g',
#   'datetime': '2024-02-25T15:00:20Z',
#   'title': 'Sheldon Steals a Movie 🎥 | The Big Bang Theory #shorts'},
#  {'video_id': 'h6LJXKAX-mk',
#   'datetime': '2024-02-24T17:00:27Z',
#   'title': 'Sheldon Breaks His Nose | The Big Bang Theory'},
#  {'video_id': 'wt1RbDjm2EU',
#   'datetime': '2024-02-24T15:00:50Z',
#   'title': 'Howard Plays It Uncool 😳  | The Big Bang Theory #shorts'},
#  {'video_id': 'FpcUcxe1h0s',
#   'datetime': '2024-02-23T23:00:09Z',
#   'title': 'Stuart Decorates His Comic Book Shop With Howard’s Mom’s Furniture | The Big Bang Theory'},
#  {'video_id': 'UH7TImUu-oQ',
#   'datetime': '2024-02-23T21:00:22Z',
#   'title': 'Bernadette is a Bully | The Big Bang Theory'},
#  {'video_id': 'QDBNRdaoXkY',
#   'datetime': '2024-02-23T17:00:17Z',
#   'title': 'Raj&#39;s Bottle Toss of Destiny | The Big Bang Theory'},
#  {'video_id': 'p3CU3rHfp0Q',
#   'datetime': '2024-02-23T15:00:59Z',
#   'title': 'Breakfast Trivia 🤔 | The Big Bang Theory #shorts'},
#  {'video_id': '5t1fZkzi2jM',
#   'datetime': '2024-02-22T21:00:05Z',
#   'title': 'Girls are a Distraction | The Big Bang Theory'},
#  {'video_id': '_0FLLKm3cDY',
#   'datetime': '2024-02-22T15:00:27Z',
#   'title': 'Sheldon Says Goodbye ✌️ | The Big Bang Theory #shorts'},
#  {'video_id': 'oOd02kj1am0',
#   'datetime': '2024-02-21T19:00:20Z',
#   'title': 'Sheldon Befriends a Little Girl | The Big Bang Theory'},
#  {'video_id': 'Wblc8Anu2DY',
#   'datetime': '2024-02-21T17:00:20Z',
#   'title': 'What Should We Destroy First? | The Big Bang Theory'},
#  {'video_id': 'DCCNXlQAMu8',
#   'datetime': '2024-02-19T21:00:06Z',
#   'title': 'Leonard Goes on the Radio | The Big Bang Theory'},
#  {'video_id': 'KgjX0nzIFTw',
#   'datetime': '2024-02-15T21:00:11Z',
#   'title': 'Sheldon Goes to a Job Recruiter | The Big Bang Theory'},
#  {'video_id': '8H_B5XrBgMc',
#   'datetime': '2024-02-14T21:00:04Z',
#   'title': 'Sheldon and Penny Miss out on Switzerland | The Big Bang Theory'},
#  {'video_id': 'KkfTIJkMOY4',
#   'datetime': '2024-02-13T21:00:17Z',
#   'title': 'Raj Has a Job Interview | The Big Bang Theory'},
#  {'video_id': 'UkOJ8UoHOA0',
#   'datetime': '2024-02-12T21:00:26Z',
#   'title': 'Sheldon Is Improbable | The Big Bang Theory'},
#  {'video_id': 'TWdjK5Mk7ss',
#   'datetime': '2024-02-08T23:00:24Z',
#   'title': 'Sheldon&#39;s Research was Sabotaged by Leonard | The Big Bang Theory'},
#  {'video_id': 'ywXDCrLMxRY',
#   'datetime': '2024-02-07T21:47:01Z',
#   'title': 'Leonard Confronts His High School Bully | The Big Bang Theory'},
#  {'video_id': 'l0d7x6CHuoo',
#   'datetime': '2024-02-07T17:00:40Z',
#   'title': 'Sheldon Gets Into Leonard&#39;s Head | The Big Bang Theory'},
#  {'video_id': 'pmypLU_fcMA',
#   'datetime': '2024-02-07T15:00:47Z',
#   'title': 'Howard Wants Butter 🧈 | The Big Bang Theory #shorts'},
#  {'video_id': '7Y2vXQBM5N8',
#   'datetime': '2024-02-06T17:00:05Z',
#   'title': 'Amy Is Sheldon&#39;s Emergency Contact | The Big Bang Theory'},
#  {'video_id': 'yvquDSgwEHQ',
#   'datetime': '2024-02-05T19:00:35Z',
#   'title': 'Leonard Is a Romance Ninja | The Big Bang Theory'},
#  {'video_id': 'pLcJCzqZvDg',
#   'datetime': '2024-02-05T17:00:40Z',
#   'title': 'Amy Meets Raj&#39;s Girlfriend | The Big Bang Theory'},
#  {'video_id': 'RpPHrYQZnRo',
#   'datetime': '2024-02-05T15:00:32Z',
#   'title': 'She Is Not for You 😠  | The Big Bang Theory #shorts'},
#  {'video_id': 'CELButFHk2o',
#   'datetime': '2024-02-04T15:00:13Z',
# ...
#   'title': 'Penny and Sheldon Go Running | The Big Bang Theory'},
#  {'video_id': '178JGZga0Pk',
#   'datetime': '2024-01-04T15:00:00Z',
#   'title': 'You Lost My Mother&#39;s Ashes?? 🛫  | The Big Bang Theory #shorts'},
#  {'video_id': 'H2XBWsxIbT8',
#   'datetime': '2024-01-03T21:00:13Z',
#   'title': 'Leslie Fixes Sheldon&#39;s Equation | The Big Bang Theory'},
#  {'video_id': 'iX4lWtcpVK0',
#   'datetime': '2024-01-02T21:00:18Z',
#   'title': 'Raj, Howard, and Leonard fight over Sheldon&#39;s Sister, Missy | The Big Bang Theory'},
#  {'video_id': 'a1sZQAoE5cI',
#   'datetime': '2024-01-02T17:00:00Z',
#   'title': 'Sheldon Really Has to Pee | The Big Bang Theory'},
#  {'video_id': 'yJPa-DZJSfo',
#   'datetime': '2023-12-31T19:00:26Z',
#   'title': 'Virtual Archery | The Big Bang Theory'},
#  {'video_id': 'YjN2ENfNjsA',
#   'datetime': '2023-12-29T17:00:33Z',
#   'title': 'Men Have Periods Too | The Big Bang Theory'},
#  {'video_id': 'FWklbNuk2VE',
#   'datetime': '2023-12-29T15:00:14Z',
#   'title': 'Leonard Bought a Time Machine | The Big Bang Theory #shorts'},
#  {'video_id': 'XAHh2dywh7o',
#   'datetime': '2023-12-28T15:00:21Z',
#   'title': 'Howard Loses His Mom | The Big Bang Theory #shorts'},
#  {'video_id': 'lbrWdAGm8Jw',
#   'datetime': '2023-12-26T21:00:17Z',
#   'title': 'Life without Sheldon | The Big Bang Theory'},
#  {'video_id': 'utcP8e_o2Zg',
#   'datetime': '2023-12-26T15:00:45Z',
#   'title': 'Sheldon Says &quot;I Love You&quot; 🤟  | The Big Bang Theory #shorts'},
#  {'video_id': '-mnEJug_jmA',
#   'datetime': '2023-12-25T21:00:00Z',
#   'title': 'Sheldon Gives Amy the Perfect Christmas Gift | The Big Bang Theory'},
#  {'video_id': 'bTIRM4SRGiM',
#   'datetime': '2023-12-25T15:00:34Z',
#   'title': 'Sheldon Grows a Mustache 👨🏻\u200d🦱 | The Big Bang Theory #shorts'},
#  {'video_id': 'kWcclJ75rvg',
#   'datetime': '2023-12-23T17:00:36Z',
#   'title': 'Penny and Leonard Share Custody of Sheldon | The Big Bang Theory'},
#  {'video_id': 'qf-w4AENP7E',
#   'datetime': '2023-12-22T15:00:45Z',
#   'title': 'Wheel of Wedding Planning! | The Big Bang Theory #shorts'},
#  {'video_id': 'Hq8RJLoMW2Q',
#   'datetime': '2023-12-21T19:00:06Z',
#   'title': 'Leonard Slept with Sheldon&#39;s Friend | The Big Bang Theory'},
#  {'video_id': '-3s3jgEM85g',
#   'datetime': '2023-12-21T15:00:00Z',
#   'title': 'It’s Hot in Here, It Must Be Summer ☀️ | The Big Bang Theory #shorts'},
#  {'video_id': 'zG3h7oYRXsw',
#   'datetime': '2023-12-20T21:00:23Z',
#   'title': 'Never Have I Ever | The Big Bang Theory'},
#  {'video_id': 'JogFZdhRmAo',
#   'datetime': '2023-12-19T21:00:12Z',
#   'title': 'Dr. Hofstadter meets Mrs. Cooper | The Big Bang Theory'},
#  {'video_id': 'Bmy6v3Vd0Nc',
#   'datetime': '2023-12-19T15:00:09Z',
#   'title': 'Sheldon Hates Secrets 🤫 | The Big Bang Theory #shorts'},
#  {'video_id': '9JmVhTMKCfc',
#   'datetime': '2023-12-17T19:00:03Z',
#   'title': 'Leonard Gets Contacts | The Big Bang Theory'},
#  {'video_id': 'YwbH_M2bK90',
#   'datetime': '2023-12-17T15:00:33Z',
#   'title': 'Sheldon and His Brain 🧠 | The Big Bang Theory #shorts'},
#  {'video_id': '6yAG3AKwhBk',
#   'datetime': '2023-12-16T15:00:05Z',
#   'title': 'It&#39;s the Comic Book Store! 🧩  | The Big Bang Theory #shorts'},
#  {'video_id': 'GTzpmU6NQNg',
#   'datetime': '2023-12-15T15:00:21Z',
#   'title': 'Raj Gets Left Underground with Rats 🐀 | The Big Bang Theory #shorts'},
#  {'video_id': 'XqH-wmWY7X4',
#   'datetime': '2023-12-13T15:00:32Z',
#   'title': 'Nerd Fight! | The Big Bang Theory #shorts'},
#  {'video_id': '2OIXOl84ZHI',
#   'datetime': '2023-12-12T15:00:01Z',
#   'title': 'Sharing a Toothbrush Holder 🪥 | The Big Bang Theory #shorts'},
#  {'video_id': '87AF2BgQRZw',
#   'datetime': '2023-12-11T15:00:06Z',
#   'title': 'The Murder Weapon 🔪 | The Big Bang Theory #shorts'},
#  {'video_id': 'azb_nkBJd0E',
#   'datetime': '2023-12-10T15:00:05Z',
#   'title': 'Sheldon&#39;s Stress Test 🎈 | The Big Bang Theory #shorts'},
#  {'video_id': 'VogQ_cTktoU',
#   'datetime': '2023-12-08T21:00:14Z',
#   'title': 'Howard Meets His Half-Brother | The Big Bang Theory'},
#  {'video_id': 'DoMXi3FqARc',
#   'datetime': '2023-12-08T19:00:12Z',
#   'title': 'The &#39;Doctor Who&#39; Door Backfires | The Big Bang Theory'},
#  {'video_id': '1yuBX3PTp6k',
#   'datetime': '2023-12-07T15:00:02Z',
#   'title': 'Indiana Jones Is Forever Ruined | The Big Bang Theory #shorts'},
#  {'video_id': 'hIphOYe61D4',
#   'datetime': '2023-12-06T17:00:42Z',
#   'title': 'Sheldon’s Mom Thought He’d Die Alone | The Big Bang Theory'},
#  {'video_id': '-9sA8klBCEY',
#   'datetime': '2023-12-06T15:00:00Z',
#   'title': 'Honeymooning In Legoland | The Big Bang Theory #shorts'},
#  {'video_id': 'skUlY_5wLOQ',
#   'datetime': '2023-12-05T15:00:44Z',
#   'title': 'Fit Bit Fraud ⌚️ | The Big Bang Theory #shorts'},
#  {'video_id': 'NQKsWCtdlO8',
#   'datetime': '2023-12-03T19:00:10Z',
#   'title': 'Bernadette’s Boss Is Afraid of Her | The Big Bang Theory'},
#  {'video_id': '_m_csr0toG4',
#   'datetime': '2023-12-03T15:00:34Z',
#   'title': '&quot;We&#39;re Getting a Turtle!&quot; 🐢  | The Big Bang Theory'},
#  {'video_id': 'hmC4ju2FoWQ',
#   'datetime': '2023-12-01T17:00:30Z',
#   'title': 'Howard Is Too Clingy | The Big Bang Theory'},
#  {'video_id': '41LWGlnwBps',
#   'datetime': '2023-11-30T21:00:03Z',
#   'title': 'Howard Wolowitz a.k.a Clogzilla | The Big Bang Theory'},
#  {'video_id': 'HomTGPd0hRM',
#   'datetime': '2023-11-30T19:00:05Z',
#   'title': 'Sheldon &amp; Amy&#39;s &quot;Love-Making&quot; Noises | The Big Bang Theory'},
#  {'video_id': 'ib-WGAj0BQQ',
#   'datetime': '2023-11-29T23:00:30Z',
#   'title': 'Stuart Volunteers to Care for Mrs. Wolowitz | The Big Bang Theory'},
#  {'video_id': 'Iat_RduXGUQ',
#   'datetime': '2023-11-29T21:00:21Z',
#   'title': 'Sheldon Can&#39;t Decide Between Xbox One or PS4 | The Big Bang Theory'},
#  {'video_id': 'iQNahJugeKE',
#   'datetime': '2023-11-29T19:00:27Z',
#   'title': 'Sheldon Tries Juggling | The Big Bang Theory'},
#  {'video_id': 'TLPrtgYCOGU',
#   'datetime': '2023-11-29T17:00:31Z',
#   'title': 'Bernadette&#39;s Dummy | The Big Bang Theory'},
#  {'video_id': 'uaXw-Q0OWr8',
#   'datetime': '2023-11-29T14:00:40Z',
#   'title': 'Howard Has Separation Anxiety | The Big Bang Theory #shorts'},
#  {'video_id': 'XtQuy9TCxPg',
#   'datetime': '2023-11-28T23:00:24Z',
#   'title': 'Raj and Emily Achieve Coitus | The Big Bang Theory'},
#  {'video_id': 'ar329l9NpqE',
#   'datetime': '2023-11-28T21:00:01Z',
#   'title': 'Sheldon has the Sex Talk with his Mom | The Big Bang Theory'},
#  {'video_id': 'MGqmd-Oe9FQ',
#   'datetime': '2023-11-28T17:00:23Z',
#   'title': 'Kids Are Better at Video Games | The Big Bang Theory'},
#  {'video_id': 's815S4szMbY',
#   'datetime': '2023-11-28T15:00:47Z',
#   'title': 'Sheldon Likes Amy&#39;s Body | The Big Bang Theory #shorts'},
#  {'video_id': 'XCamDF1HdyY',
#   'datetime': '2023-11-27T23:05:41Z',
#   'title': 'Sheldon and Penny Visit a Psychic | The Big Bang Theory'},
#  {'video_id': 'GUltQahxh3o',
#   'datetime': '2023-11-27T15:00:19Z',
#   'title': 'The Parenting Book Works on Sheldon 📖 | The Big Bang Theory #shorts'},
#  {'video_id': '1HA8pvZNFfI',
#   'datetime': '2023-11-26T19:00:00Z',
#   'title': 'Sheldon Works on Two Projects at Once | The Big Bang Theory'},
#  {'video_id': 'n0TS61tyIGQ',
#   'datetime': '2023-11-26T15:00:40Z',
#   'title': 'Beverly Makes Leonard Cry in a Good Way 🥲 | The Big Bang Theory #shorts'},
#  {'video_id': 'tBRHLADcjqo',
#   'datetime': '2023-11-25T15:00:50Z',
#   'title': '&quot;Leonard, I&#39;m Sick!&quot; 🤒 | The Big Bang Theory #shorts'},
#  {'video_id': 'DCN3LuRPSjM',
#   'datetime': '2023-11-24T21:00:07Z',
#   'title': 'Sheldon Doesn&#39;t Want a Dining Room Table | The Big Bang Theory'},
#  {'video_id': 'BOZ78E2Hxas',
#   'datetime': '2023-11-24T15:00:14Z',
#   'title': 'Is This in Poor Taste? 🦽 | The Big Bang Theory #shorts'},
#  {'video_id': 'Wip7pKKa2_0',
#   'datetime': '2023-11-23T21:00:15Z',
#   'title': 'Penny&#39;s Thanksgiving Annulment | The Big Bang Theory'},
#  {'video_id': 'r10cfA5v72M',
#   'datetime': '2023-11-23T15:00:41Z',
#   'title': 'Sheldon&#39;s First Sip of Coffee ☕️ | The Big Bang Theory #shorts'},
#  {'video_id': '4cGvT_xiCKo',
#   'datetime': '2023-11-22T21:00:03Z',
#   'title': 'The Guys Miss Out on Comic-Con | The Big Bang Theory'},
#  {'video_id': '5fsDDls65AM',
#   'datetime': '2023-11-22T15:00:04Z',
#   'title': 'Howard&#39;s Space Toilet Doesn&#39;t Work 🚽 | The Big Bang Theory #shorts'},
#  {'video_id': 'nIg6Fgkx_kk',
#   'datetime': '2023-11-21T15:00:43Z',
#   'title': 'Stuart Looks Like an Oompa Loompa | The Big Bang Theory #shorts'},
#  {'video_id': 'orDUxNZYKdo',
#   'datetime': '2023-11-19T19:00:24Z',
#   'title': 'Sheldon Is in Charge of Raj’s Finances | The Big Bang Theory'},
#  {'video_id': 'KBmKEcaAuZM',
#   'datetime': '2023-11-19T15:00:20Z',
#   'title': 'Howdini&#39;s Greatest Trick | The Big Bang Theory #shorts'},
#  {'video_id': 'UsMzhz4NSyM',
#   'datetime': '2023-11-18T15:00:23Z',
#   'title': 'The Counsel Of Sheldons Take Roll | The Big Bang Theory #shorts'},
#  {'video_id': 'g8Gr2dKJCaE',
#   'datetime': '2023-11-16T20:00:17Z',
#   'title': 'Leonard and the Itchy Sweater | The Big Bang Theory #shorts'},
#  {'video_id': 'W2q0AY4U7CI',
#   'datetime': '2023-11-15T19:00:11Z',
#   'title': 'Leonard Uses Trains To Get Rid of Sheldon | The Big Bang Theory'},
#  {'video_id': 'igpl2JPqpCk',
#   'datetime': '2023-11-15T15:00:42Z',
#   'title': 'PMS? | The Big Bang Theory #shorts'},
#  {'video_id': 'pzkJuDPYk2Q',
#   'datetime': '2023-11-14T15:00:42Z',
#   'title': 'Sheldon&#39;s Life Without Leonard | The Big Bang Theory #short'},
#  {'video_id': '0ekq_qHXxIw',
#   'datetime': '2023-11-11T19:00:00Z',
#   'title': 'The Baby Sounds Like Howard&#39;s Mom | The Big Bang Theory'},
#  {'video_id': '4CAuuIdOlxo',
#   'datetime': '2023-11-11T17:00:04Z',
#   'title': 'Bernadette Can Read Sheldon&#39;s Mind | The Big Bang Theory'},
#  {'video_id': 'eCi4ZtRGUVY',
#   'datetime': '2023-11-06T17:00:39Z',
#   'title': 'Sheldon&#39;s Video Message to Himself | The Big Bang Theory'},
#  {'video_id': 'Yd47KlWK9x0',
#   'datetime': '2023-11-05T19:00:24Z',
#   'title': 'Picking Teams for Paintball | The Big Bang Theory'},
#  {'video_id': '-Ipw0_msT_U',
#   'datetime': '2023-11-02T20:00:00Z',
#   'title': 'Sheldon Needs Closure | The Big Bang Theory'},
#  {'video_id': '2BMI56oL_IQ',
#   'datetime': '2023-11-02T18:00:01Z',
#   'title': 'Penny Likes Decisive Leonard | The Big Bang Theory'},
#  {'video_id': 'GecQwh2iwJY',
#   'datetime': '2023-11-01T22:00:06Z',
#   'title': 'The Battle for Tenure | The Big Bang Theory'},
#  {'video_id': '_Zdpa7EURbo',
#   'datetime': '2023-11-01T20:33:56Z',
#   'title': 'The Closet and the Letter | The Big Bang Theory'},
#  {'video_id': 'SwtqBiL-M-4',
#   'datetime': '2023-10-30T16:00:25Z',
#   'title': 'Penny &amp; Bernadette Dish on Raj | The Big Bang Theory'},
#  {'video_id': 'IgjULQ5A_Zc',
#   'datetime': '2023-10-29T14:00:22Z',
#   'title': 'What Did Tam Do? | The Big Bang Theory'},
#  {'video_id': 'KMWbQvoae9s',
#   'datetime': '2023-10-28T18:00:07Z',
#   'title': 'Funny Moments from Season 10 | The Big Bang Theory'},
#  {'video_id': 'TSbgevFmfPc',
#   'datetime': '2023-10-17T20:00:08Z',
#   'title': 'Alex Hits on Leonard | The Big Bang Theory'},
#  {'video_id': '_jOvSCMawGk',
#   'datetime': '2023-10-12T16:00:32Z',
#   'title': 'The Comic Book Store is Packed | The Big Bang Theory'},
#  {'video_id': '7aHlBW9hg8Y',
#   'datetime': '2023-10-10T16:00:08Z',
#   'title': 'Penny&#39;s Drunken Video Message | The Big Bang Theory'},
#  {'video_id': 'TC_hbB_uApA',
#   'datetime': '2023-10-07T18:00:09Z',
#   'title': 'Sheldon Gets Pulled Over | The Big Bang Theory'},
#  {'video_id': 'MgoG_L2N1oI',
#   'datetime': '2023-10-05T18:00:22Z',
#   'title': 'Sheldon Tries Wearing Flip-Flops | The Big Bang Theory'},
#  {'video_id': 'glB6tm1ZNWM',
#   'datetime': '2023-10-02T18:00:29Z',
#   'title': 'Penny is Sheldon&#39;s Babysitter | The Big Bang Theory'},
#  {'video_id': 'z435hywrRog',
#   'datetime': '2023-10-02T16:00:49Z',
#   'title': 'Sheldon &amp; Amy Share a Toothbrush Holder | The Big Bang Theory'},
#  {'video_id': '-XK5igy9ryY',
#   'datetime': '2023-09-29T14:00:00Z',
#   'title': 'Sheldon Starts a College Fund for Howard&#39;s Baby | The Big Bang Theory'},
#  {'video_id': 'uiugfkrH9ak',
#   'datetime': '2023-09-25T18:00:24Z',
#   'title': 'Sheldon&#39;s Birthday Gift for Amy | The Big Bang Theory'},
#  {'video_id': 'RMJoY2wOaPI',
#   'datetime': '2023-09-23T14:00:20Z',
#   'title': 'Sick Sheldon is the WORST | The Big Bang Theory'},
#  {'video_id': 'UGGb8PX1ka0',
#   'datetime': '2023-09-22T16:00:25Z',
#   'title': 'Funny Moments from Season 9 | The Big Bang Theory'},
#  {'video_id': 'wRW1lvGJotY',
#   'datetime': '2023-09-21T22:00:38Z',
#   'title': 'Leonard and Penny Attempt to Date Again | The Big Bang Theory'},
#  {'video_id': 'lW4aE6xdcyE',
#   'datetime': '2023-09-21T20:00:13Z',
#   'title': 'Leonard Asks Penny on a Date, Again | The Big Bang Theory'},
#  {'video_id': 'jXxlcSz3kIg',
#   'datetime': '2023-09-20T16:00:41Z',
#   'title': 'The Sheldon Cooper Girlfriend Challenge | The Big Bang Theory'},
#  {'video_id': 'HzWzopeCCaY',
#   'datetime': '2023-09-18T14:00:10Z',
#   'title': 'Funny Moments from Season 8 | The Big Bang Theory'},
#  {'video_id': 'WKlcrMJatkY',
#   'datetime': '2023-09-17T14:00:18Z',
#   'title': 'Penny &amp; Sheldon Kiss | The Big Bang Theory'},
#  {'video_id': '6YmwtJbUF_0',
#   'datetime': '2023-09-13T14:00:03Z',
#   'title': 'Funny Moments from Season 7 | The Big Bang Theory'},
#  {'video_id': 'Fda0RZG9b0I',
#   'datetime': '2023-09-12T18:00:06Z',
#   'title': 'Penny &amp; Sheldon Quiz Each Other | The Big Bang Theory'},
#  {'video_id': 'UoeZEUH6uu8',
#   'datetime': '2023-09-12T16:00:19Z',
#   'title': 'The Government is After Howard | The Big Bang Theory'},
#  {'video_id': 'Hcgd9g_2iH0',
#   'datetime': '2023-09-10T22:00:07Z',
#   'title': 'Funny Moments from Season 6 | The Big Bang Theory'},
#  {'video_id': 'JkBQ53wmn5s',
#   'datetime': '2023-09-08T14:00:16Z',
#   'title': 'Howard&#39;s Mom Dies | The Big Bang Theory'},
#  {'video_id': '1T6bJWyUi7o',
#   'datetime': '2023-09-07T22:00:01Z',
#   'title': 'Professor Sheldon | The Big Bang Theory'},
#  {'video_id': 'rW0LVVEeod8',
#   'datetime': '2023-09-07T20:00:12Z',
#   'title': 'Howard Meets Glenn | The Big Bang Theory'},
#  {'video_id': 'hSk08JDgyn8',
#   'datetime': '2023-09-07T14:00:32Z',
#   'title': 'Leonard is Moving Out | The Big Bang Theory'},
#  {'video_id': '75XdXdVa-B8',
#   'datetime': '2023-09-05T20:06:44Z',
#   'title': 'Will You Marry Me? | The Big Bang Theory'},
#  {'video_id': 'wAXjyZa0dXQ',
#   'datetime': '2023-09-05T16:00:46Z',
#   'title': 'Funny Moments from Season 5 | The Big Bang Theory'},
#  {'video_id': '0DtNIc7YpFI',
#   'datetime': '2023-09-01T22:30:00Z',
#   'title': 'Sheldon Goes to Jail | The Big Bang Theory'},
#  {'video_id': 'M_iHcDAurEE',
#   'datetime': '2023-09-01T14:00:21Z',
#   'title': 'Sheldon Asks Penny Out | The Big Bang Theory'},
#  {'video_id': 'M_iHcDAurEE',
#   'datetime': '2023-09-01T14:00:21Z',
#   'title': 'Sheldon Asks Penny Out | The Big Bang Theory'},
#  {'video_id': '8CHayLFMvFM',
#   'datetime': '2023-08-31T14:00:08Z',
#   'title': 'Funny Moments from Season 4 | The Big Bang Theory'},
#  {'video_id': 'URrq5bSJq2Q',
#   'datetime': '2023-08-28T14:00:16Z',
#   'title': 'Funny Moments from Season 3 | The Big Bang Theory'},
#  {'video_id': 'q9GScvO-ZpE',
#   'datetime': '2023-08-21T20:00:12Z',
#   'title': 'Sheldon&#39;s Girl-Date-Person | The Big Bang Theory'},
#  {'video_id': 'oVS7kTuzV1M',
#   'datetime': '2023-08-21T14:00:35Z',
#   'title': 'Funny Moments from Season 1 | The Big Bang Theory'},
#  {'video_id': '72fvP_tNNYM',
#   'datetime': '2023-08-18T22:00:03Z',
#   'title': 'Sheldon Gets Hit On | The Big Bang Theory'},
#  {'video_id': 'tU8Tjdy6Ogg',
#   'datetime': '2023-08-18T16:00:46Z',
#   'title': 'Foamy Vengeance | The Big Bang Theory'},
#  {'video_id': 's5C6H7DPy2c',
#   'datetime': '2023-08-18T14:00:43Z',
#   'title': 'Penny is Jealous of the New Girl | The Big Bang Theory'},
#  {'video_id': 'HfQAqnIG2_8',
#   'datetime': '2023-08-17T16:00:14Z',
#   'title': 'Penny Goes to the Comic Book Store | The Big Bang Theory'},
#  {'video_id': 'dvjvYUOEjgg',
#   'datetime': '2023-08-11T16:00:36Z',
#   'title': 'Howard &amp; Raj Get Diagnosed by Leonard&#39;s Mom | The Big Bang Theory'},
#  {'video_id': 'fuFcd5LoebQ',
#   'datetime': '2023-07-28T22:00:19Z',
#   'title': 'Sheldon is a Football Genius | The Big Bang Theory'}]

# %%
# write data to file
pl.DataFrame(video_record_list).write_parquet('video-ids.parquet')
pl.DataFrame(video_record_list).write_csv('video-ids.csv')
